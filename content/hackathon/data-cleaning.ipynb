# %% [markdown]
# ![Banner](https://github.com/Data-Dunkers/lessons/blob/main/images/top-banner.jpg?raw=true)

# %% [markdown]
# # Data Cleaning
#
# Data cleaning is the process of fixing problems in a data set. We are going to start with data from the 2024-2025 Indiana Pacers NBA season.

# %%
import piplite, pyodide
await piplite.install(['pandas', 'plotly', 'nbformat', 'statsmodels'])
import pandas as pd
 
df = pd.read_csv(pyodide.http.open_url("https://raw.githubusercontent.com/Data-Dunkers/data/refs/heads/main/NBA/team/2024-2025/IND_2024-2025_players_original.csv"))
df

# %% [markdown]
# ## 1. Flagging Traded Players
#
# You'll notice that the `Name` column contains the player name and their position. In some cases there is also a `*`, indicating that the player was traded during the season.
#
# Our first step in cleaning up that column will be to make a new `Traded` column and set it to True for any players with a `*`.

# %%
df['Traded'] = df['Name'].str.contains('*', regex=False)
df

# %% [markdown]
# ## 2. Cleaning Names
#
# Now we can remove the `*` characters from the `Name` column, and strip out any extra spaces.

# %%
df['Name'] = df['Name'].str.replace('*', '', regex=False).str.strip()
df

# %% [markdown]
# ## 3. Extracting Position
#
# Now to extract the `Position` from the `Name` column by splitting on the ` ` character and extracting the part after the last space.

# %%
df['Position'] = df['Name'].str.split(' ').str[-1]
df

# %% [markdown]
# ## 4. Finalizing Names
#
# To remove the position information from the name column is similar, we want everything up to the last space.

# %%
df['Name'] = df['Name'].str.split(' ').str[:-1]
df['Name'] = df['Name'].str.join(' ')
df

# %% [markdown]
# ## 5. Handling Totals and Missing Values
#
# The total row (row 22) might need a manual name fix, and we should also replace any `NaN` (not number) values with the value `0`.

# %%
df.loc[22, 'Name'] = 'Total'
df = df.fillna(0)
df

# %% [markdown]
# ## 6. Reordering Columns
#
# As a final step, we can reorder the columns to make the dataset easier to read.

# %%
cols = ['Name', 'Position', 'Traded', 'GP', 'GS', 'MIN', 'PTS', 'OR', 'DR', 'REB', 
        'AST', 'STL', 'BLK', 'TO', 'PF', 'AST/TO', 'FGM', 'FGA', 'FG%', '3PM', 
        '3PA', '3P%', 'FTM', 'FTA', 'FT%', '2PM', '2PA', '2P%', 'SC-EFF', 'SH-EFF']
df = df[cols]
df.head()

# %% [markdown]
# ## Reflection Questions
#
# 1. Why do you think we set `regex=False` when checking for the `*` character?
# 2. Explain the difference between `.str.split(' ').str[-1]` and `.str.split(' ').str[:-1]`.
# 3. How would you modify the code to create a `FirstName` and `LastName` column instead of keeping the full name together?

# %%
# https://docs.google.com/forms/d/e/1FAIpQLSdtOk_P1KvvhG5w_FmXCGSFzUdQhRCGw5XLrw2laKGCgdTo6Q/viewform?usp=pp_url&entry.1798553786=' + encodeURIComponent(nickname) + '&entry.164145481=' + encodeURIComponent(challengeName) + '&entry.813479616=' + encodeURIComponent(answerText);
import nbformat, urllib.parse
from IPython.display import display, HTML

NB_NAME = 'data-cleaning'
BASE = "https://docs.google.com/forms/d/e/1FAIpQLSdtOk_P1KvvhG5w_FmXCGSFzUdQhRCGw5XLrw2laKGCgdTo6Q/viewform?usp=pp_url"
nickname = "StudentName" # Or input("Enter Nickname: ")

# 1. Read the cell above
with open(NB_NAME, 'r', encoding='utf-8') as f:
    nb = nbformat.read(f, as_version=4)

# 2. Find the content of the markdown cell right before this one
# We assume the last cell modified/run is the current one
ans_text = next(c.source for c in reversed(nb.cells) if c.cell_type == 'markdown')

# 3. Generate Link
params = {
    'entry.1798553786': nickname,
    'entry.164145481': 'data-cleaning',
    'entry.813479616': ans_text
}
url = f"{BASE}&{urllib.parse.urlencode(params)}"

display(HTML(f'<a href="{url}" target="_blank" style="background:#1a73e8;color:white;padding:8px 15px;border-radius:5px;text-decoration:none;">🚀 Submit Challenge</a>'))

# %% [markdown]
# [![Data Dunkers License](https://github.com/Data-Dunkers/lessons/blob/main/images/bottom-banner.jpg?raw=true)](https://github.com/Data-Dunkers/lessons/blob/main/LICENSE.md)
